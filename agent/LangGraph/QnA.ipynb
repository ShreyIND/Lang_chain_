# %%
from langgraph.graph import StateGraph,END,START

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm=ChatGoogleGenerativeAI(model="gemini-flash-latest",google_api_key="AIzaSyAOtKTVfWYzCY_kFoSKZ7QOZhY6RZj791U")

# %%
from typing import TypedDict
class LLMstate(TypedDict):
    question:str
    ans:str

# %%
def llm_qa(state:LLMstate)->LLMstate:
    question=state['question']
    prompt=f'Answer the following {question}'
    answer=llm.invoke(prompt).content
    state['ans']=answer
    return state

# %%
graph=StateGraph(LLMstate)

# %%
graph.add_node("llm_qa",llm_qa)

# %%
graph.add_edge(START,"llm_qa")
graph.add_edge("llm_qa",END)

# %%
workflow=graph.compile()

# %%
intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['ans'])
# Out:
# [{'type': 'text', 'text': 'The distance between the Earth and the Moon is not constant because the Moon orbits the Earth in an elliptical (oval-shaped) path.\n\nHere are the key measurements:\n\n*   **Average Distance:** Approximately **384,400 kilometers (238,855 miles)**.\n*   **Perigee (Closest):** About **363,300 kilometers (225,744 miles)**.\n*   **Apogee (Farthest):** About **405,500 kilometers (251,966 miles)**.\n\n### To put that distance into perspective:\n1.  **30 Earths:** You could fit about 30 Earth-sized planets in the space between the Earth and the Moon.\n2.  **Light Speed:** It takes light approximately **1.3 seconds** to travel from the Moon to the Earth.\n3.  **Travel Time:** If you could drive a car at a constant 100 km/h (62 mph) to the Moon, it would take you about **160 days** to get there. The Apollo astronauts typically took about **3 days** to reach lunar orbit using a rocket.', 'extras': {'signature': '...'}}]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 final_state.text
#
# AttributeError: 'dict' object has no attribute 'text'
